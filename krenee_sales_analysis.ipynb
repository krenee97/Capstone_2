# %% [markdown]
# # Sales Territory Analysis - EmporiUm
# ## Project Overview
# This notebook analyze sales data for EmporiUm, a student bookstore chain selling books, tech gear, and art supplies. The goal is to compare performance across two assigned sales territories and provide marketing recommendations.
#
# ## Sales Territores Analyzed
# - Territory 1: Colorado | Mananger: Jim Heck | Region: West
# - Territory 2: Texas | Mananger: Jeff "Howdy" Richards | Region: South

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Customer List
customers = pd.read_csv('customer_list .csv' , sep='|')
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    object
#  2   time          521 non-null    object
#  3   name          521 non-null    object
#  4   email         521 non-null    object
#  5   phone         520 non-null    object
#  6   sms-opt-out   520 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 28.6+ KB

# %%
# Products
products = pd.read_csv('Products .csv')
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    object
#  1   Product        669 non-null    object
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 21.0+ KB

# %%
# Product Categories
product_categories = pd.read_csv('ProductCategories .csv')
product_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     object
#  2   SubcategoryID  52 non-null     object
#  3   Subcategory    52 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ KB

# %%
# Store Details
store_details = pd.read_csv('StoreDetail .csv')
store_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    object
#  1   State              111 non-null    object
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    object
#  4   Region             111 non-null    object
#  5   Region Director    111 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 5.3+ KB

# %%
# Store Sales
store_sales = pd.read_csv('StoreSales .csv')
store_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  object
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  object
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 12.8+ MB

# %% [markdown]
# ## Core Marketing Analysis

# %%
# Question 1: Territroy manangers and store IDs/cities for each territory
colorado_stores = store_details[store_details['State'] == 'Colorado']
texas_stores = store_details[store_details['State'] == 'Texas']

print("=" * 40)
print("COLORADO STORES")
print("=" * 40)
print(colorado_stores[['Store Location', 'State', 'Store ID', 'Territory Manager']])

print("\n" + "=" * 40)
print("TEXAS STORES")
print("=" * 40)
print(texas_stores[['Store Location', 'State', 'Store ID', 'Territory Manager']])
# Out:
# ========================================
# COLORADO STORES
# ========================================
#     Store Location     State  Store ID Territory Manager
# 0           Aurora  Colorado       701          Jim Heck
# 1         Berthoud  Colorado       702          Jim Heck
# 2          Boulder  Colorado       703          Jim Heck
# 3      Castle Rock  Colorado       704          Jim Heck
# 4           Denver  Colorado       705          Jim Heck
# 5        Englewood  Colorado       706          Jim Heck
# 6     Fort Collins  Colorado       707          Jim Heck
# 7   Grand Junction  Colorado       708          Jim Heck
# 8          Greeley  Colorado       709          Jim Heck
# 9        Lafayette  Colorado       710          Jim Heck
# 10       Littleton  Colorado       711          Jim Heck
# 11        Loveland  Colorado       712          Jim Heck
# 12        Milliken  Colorado       713          Jim Heck
# 13      New Castle  Colorado       714          Jim Heck
# 14          Parker  Colorado       715          Jim Heck
# 15         Sedalia  Colorado       716          Jim Heck
# 16        Thornton  Colorado       717          Jim Heck
# 17     Wheat Ridge  Colorado       718          Jim Heck
#
# ========================================
# TEXAS STORES
# ========================================
#     Store Location  State  Store ID      Territory Manager
# 100      Arlington  Texas       901  Jeff "Howdy" Richards
# 101         Austin  Texas       902  Jeff "Howdy" Richards
# 102        Bacliff  Texas       903  Jeff "Howdy" Richards
# 103        Baytown  Texas       904  Jeff "Howdy" Richards
# 104       Beaumont  Texas       905  Jeff "Howdy" Richards
# 105     Cedar Park  Texas       906  Jeff "Howdy" Richards
# 106         Dallas  Texas       907  Jeff "Howdy" Richards
# 107         Denton  Texas       908  Jeff "Howdy" Richards
# 108         Desoto  Texas       909  Jeff "Howdy" Richards
# 109     Fort Worth  Texas       910  Jeff "Howdy" Richards
# 110     Georgetown  Texas       911  Jeff "Howdy" Richards

# %%
# Question 2: Monthly total revenue for each territory

# Merge store_sales with store_details to get state info
sales_with_state = store_sales.merge(store_details[['Store ID', 'State']], on='Store ID', how='left')

# Filter for Colorado and Texas
colorado_sales = sales_with_state[sales_with_state['State'] == 'Colorado']
texas_sales = sales_with_state[sales_with_state['State'] == 'Texas']

# Convert Transaction Date to datetime
colorado_sales = colorado_sales.copy()
texas_sales = texas_sales.copy()
colorado_sales['Transaction Date'] = pd.to_datetime(colorado_sales['Transaction Date'])
texas_sales['Transaction Date'] = pd.to_datetime(texas_sales['Transaction Date'])

# Group by month
colorado_monthly = colorado_sales.groupby(colorado_sales['Transaction Date'].dt.to_period('M'))['Sale Amount'].sum()
texas_monthly = texas_sales.groupby(texas_sales['Transaction Date'].dt.to_period('M'))['Sale Amount'].sum()

print("=" * 40)
print("COLORADO MONTHLY REVENUE")
print("=" * 40)
print(colorado_monthly)

print("\n" + "=" * 40)
print("TEXAS MONTHLY REVENUE")
print("=" * 40)
print(texas_monthly)
# Out:
# ========================================
# COLORADO MONTHLY REVENUE
# ========================================
# Transaction Date
# 2022-01     77950.98
# 2022-02     80315.69
# 2022-03     82516.36
# 2022-04     89350.31
# 2022-05     94892.89
# 2022-06     86847.70
# 2022-07     94048.49
# 2022-08     87058.36
# 2022-09     84206.09
# 2022-10     78706.96
# 2022-11     76920.06
# 2022-12     78541.63
# 2023-01    127097.69
# 2023-02    118165.45
# 2023-03    113336.10
# 2023-04    131835.33
# 2023-05    126201.30
# 2023-06    110745.70
# 2023-07    137070.84
# 2023-08    132936.24
# 2023-09    137022.60
# 2023-10    118913.30
# 2023-11    122127.52
# 2023-12    112438.65
# 2024-01    130507.83
# 2024-02    104570.81
# 2024-03    133808.20
# 2024-04    124228.43
# 2024-05    116437.33
# 2024-06    131379.21
# 2024-07    132936.24
# 2024-08    139385.22
# 2024-09    116550.68
# 2024-10    124204.24
# 2024-11    110361.93
# 2024-12    127097.69
# 2025-01    181006.05
# 2025-02    165726.20
# 2025-03    183144.31
# 2025-04    168853.86
# 2025-05    186318.66
# 2025-06    167246.64
# 2025-07    204640.58
# 2025-08    209591.63
# 2025-09    196114.94
# 2025-10    330762.82
# 2025-11    220240.73
# 2025-12    208271.75
# Freq: M, Name: Sale Amount, dtype: float64
#
# ========================================
# TEXAS MONTHLY REVENUE
# ========================================
# Transaction Date
# 2022-01     40857.20
# 2022-02     52729.22
# 2022-03     49214.95
# 2022-04     55229.25
# 2022-05     49696.98
# 2022-06     45208.26
# 2022-07     48308.66
# 2022-08     49641.33
# 2022-09     47977.04
# 2022-10     50543.10
# 2022-11     41402.48
# 2022-12     49055.84
# 2023-01     72298.63
# 2023-02     45399.37
# 2023-03     67468.76
# 2023-04     76712.34
# 2023-05     74059.48
# 2023-06     68340.04
# 2023-07     63941.07
# 2023-08     60700.57
# 2023-09     69674.13
# 2023-10     64725.08
# 2023-11     65553.06
# 2023-12     78994.26
# 2024-01     49824.16
# 2024-02     64549.05
# 2024-03     80723.94
# 2024-04     70047.88
# 2024-05     70733.08
# 2024-06     61548.03
# 2024-07     60700.57
# 2024-08     71514.05
# 2024-09     62885.16
# 2024-10     70341.95
# 2024-11     74205.37
# 2024-12     72298.63
# 2025-01    101046.12
# 2025-02     95007.06
# 2025-03    101490.54
# 2025-04     81348.63
# 2025-05     85801.23
# 2025-06     87182.86
# 2025-07     91246.68
# 2025-08     98630.93
# 2025-09    109065.94
# 2025-10    168955.72
# 2025-11    105400.74
# 2025-12     95570.59
# Freq: M, Name: Sale Amount, dtype: float64

# %%
# Question 3: Rank store preformance in each territory

colorado_store_sales = colorado_sales.groupby('Store ID')['Sale Amount'].sum().reset_index()
colorado_store_sales = colorado_store_sales.merge(store_details[['Store ID', 'Store Location']], on='Store ID')
colorado_store_sales = colorado_store_sales.sort_values(by='Sale Amount', ascending=False)
colorado_store_sales['Rank'] = range(1, len(colorado_store_sales) + 1)

texas_store_sales = texas_sales.groupby('Store ID')['Sale Amount'].sum().reset_index()
texas_store_sales = texas_store_sales.merge(store_details[['Store ID', 'Store Location']], on='Store ID')
texas_store_sales = texas_store_sales.sort_values(by='Sale Amount', ascending=False)
texas_store_sales['Rank'] = range(1, len(texas_store_sales) + 1)

print("=" * 40)
print("COLORADO STORE PERFORMANCE")
print("=" * 40)
print(colorado_store_sales[['Store Location', 'Sale Amount', 'Rank']])

print("\n" + "=" * 40)
print("TEXAS STORE PERFORMANCE")
print("=" * 40)
print(texas_store_sales[['Store Location', 'Sale Amount', 'Rank']])
# Out:
# ========================================
# COLORADO STORE PERFORMANCE
# ========================================
#     Store Location  Sale Amount  Rank
# 4           Denver    917471.53     1
# 8          Greeley    640368.11     2
# 5        Englewood    344647.48     3
# 9        Lafayette    337169.61     4
# 2          Boulder    321197.88     5
# 15         Sedalia    319776.13     6
# 0           Aurora    317198.67     7
# 7   Grand Junction    306834.49     8
# 6     Fort Collins    302660.34     9
# 3      Castle Rock    299122.02    10
# 13      New Castle    298504.41    11
# 11        Loveland    297702.56    12
# 16        Thornton    294530.76    13
# 10       Littleton    289514.27    14
# 12        Milliken    284586.13    15
# 1         Berthoud    281182.34    16
# 17     Wheat Ridge    280896.55    17
# 14          Parker    279268.94    18
#
# ========================================
# TEXAS STORE PERFORMANCE
# ========================================
#    Store Location  Sale Amount  Rank
# 4        Beaumont    637818.90     1
# 9      Fort Worth    351772.59     2
# 8          Desoto    330720.12     3
# 5      Cedar Park    312628.27     4
# 3         Baytown    298163.16     5
# 7          Denton    298111.45     6
# 0       Arlington    292987.49     7
# 1          Austin    291145.00     8
# 2         Bacliff    280714.34     9
# 10     Georgetown    269344.64    10
# 6          Dallas     54444.05    11

# %%
# Question 4: Top customers by matching cutsomers ID to rewards ID

# Merge store_sales with store_details to get state
colorado_cutsomers = colorado_sales.groupby('RewardsID')['Sale Amount'].sum().reset_index()
texas_customers = texas_sales.groupby('RewardsID')['Sale Amount'].sum().reset_index()

# Merge with cutsomer list
colorado_customers = colorado_cutsomers.merge(customers[['cust_id', 'name']],
                                              left_on='RewardsID', 
                                              right_on='cust_id',
                                              how='left')
texas_customers = texas_customers.merge(customers[['cust_id', 'name']],
                                            left_on='RewardsID', 
                                            right_on='cust_id',
                                            how='left')

# Sort anf get top 10
colorado_customers = colorado_customers.sort_values(by='Sale Amount', ascending=False).head(10)
texas_customers = texas_customers.sort_values(by='Sale Amount', ascending=False).head(10)

print("=" * 40)
print("TOP 10 COLORADO CUSTOMERS")
print("=" * 40)
print(colorado_customers[['name','RewardsID', 'Sale Amount']])

print("\n" + "=" * 40)
print("TOP 10 TEXAS CUSTOMERS")
print("=" * 40)
print(texas_customers[['name','RewardsID', 'Sale Amount']])
# Out:
# ========================================
# TOP 10 COLORADO CUSTOMERS
# ========================================
#                 name  RewardsID  Sale Amount
# 244   Gloria Mendoza      245.0      7855.66
# 374       C.J. Cregg      375.0      5006.57
# 379    Abbey Bartlet      380.0      4605.19
# 241    Lorna Morello      242.0      4381.15
# 278     Adrian Veidt      279.0      4365.77
# 2      Monica Geller        3.0      4173.74
# 208     Vivian Banks      209.0      4125.13
# 463      Kima Greggs      464.0      4096.06
# 188      Abby Whelan      189.0      3927.14
# 127  Sonny Corinthos      128.0      3842.41
#
# ========================================
# TOP 10 TEXAS CUSTOMERS
# ========================================
#                        name  RewardsID  Sale Amount
# 341             Nate Jacobs      344.0      5240.86
# 470  Christopher Moltisanti      474.0      3479.46
# 100                Jodie L.      102.0      3464.91
# 166                  Darius      168.0      3400.35
# 268                Maeby F.      271.0      3127.53
# 482           Pete Campbell      486.0      2845.84
# 198                  Animal      200.0      2843.74
# 387                 Dot Com      390.0      2757.26
# 259               Hollyhock      262.0      2715.74
# 151               Chachi A.      153.0      2708.13

# %%
print(customers.columns.tolist())
# Out:
# ['cust_id|date|time|name|email|phone|sms-opt-out ']
